# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrobrenzanbatistute2009-code/INTMI2025/blob/main/ALP_PedroBrenzan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritimo e lógica de programação

# %% [markdown]
# ##Variáveis e Operadores

# %%
x = 55   #Isso é uma variavél
print(x)
# Out:
# 55

# %% [markdown]
# ##operadores
# adição +
#
# subtração -
#
# divisão /
#
# Multiplicação *
#
# Resto da divisão %
#
# Divisão inteira //
#
# Exponenciação **

# %%
numero1 = 10
numero2 = 5

print(" a soma é igual a:", numero1 + numero2)
print(" a subtração é igual a:", numero1 - numero2)
print(" a multiplicação é igual a:", numero1 * numero2)
print(" a divisão é igual a:", numero1 / numero2)
print(" a resto de divisão é igual a:", numero1 % numero2)
print(" a divisão inteira é igual a:", numero1 // numero2)
print(" a exponenciação é igual a:", numero1 ** numero2)
# Out:
#  a soma é igual a: 15
#  a subtração é igual a: 5
#  a multiplicação é igual a: 50
#  a divisão é igual a: 2.0
#  a resto de divisão é igual a: 0
#  a divisão inteira é igual a: 2
#  a exponenciação é igual a: 100000

# %%
idade = input("Digite a sua idade:")
# Out:
# Digite a sua idade:16

# %% [markdown]
# ##tipos de dados
# int - para números inteiros (1 , 2, 3)
#
# str - para palavras e textos (palavra)
#
# float - para números com vigula (1,5 , 2,3)
#
# bool -  para bínarios,verdadeiro ou falso (true,false)

# %%
altura = float(input("digite sua altura: "))
peso = float(input(" digite seu peso: "))

imc = peso / (altura * altura)
print("seu imc é: ", imc)
# Out:
# digite sua altura: 1.71
#  digite seu peso: 58
# seu imc é:  19.835162956123252

# %% [markdown]
# ##Estrutura Condicional
#
# if - se
#
# elif - senão se
#
# else - senão

# %%
nota = float(input("Digite  sua nota: "))
if( nota >=7):
  print("aprovado")
elif (nota >=5):
  print("recuperação")
else:
  print("reprovado")
# Out:
# Digite  sua nota: 8
# aprovado

# %% [markdown]
# crie um algoritimo que leia a sua idade mostre as frases na ela:
#
# até 12 anos - Você é uma criança!
#
# 13 - 18 -Você é adolescente!
#
# 19 - 60 - Você é adulto!
#
# 60 - Você é idoso!

# %%
idade = int(input("Digite a sua idade"))
if(idade <=12):
  print("Você é uma criança")
elif (idade >= 13 and idade <= 18):
  print("Você é um adolescente")
elif (idade >= 19 and idade <= 60):
  print("Você é um adulto")
else:
  print("Você é um idoso")
# Out:
# Digite a sua idade16
# Você é um adolescente

# %% [markdown]
# Crie um algoritimo que receba 2 numeros e escolha que mostre o seguinte menu:
# selecione o sinal
# 1 - adição
# 2 - Subtração
# 3 - multiplicação
# 4 - Divisão
# caso não esolha um numero válido apreça na tela: Opção inválida!
# se escolher 1 soe os 2 números e mostre o resultado.
# se escolher 2 subtraia os 2 números e mostre o resultado.
# e assim como as outras opções
